# %%
#@title

import ipywidgets as widgets
from IPython.display import display

# Vergleichsuntersuchung

##Definition der Variablen
kvgl = 'Keine Vergleichsuntersuchung vorliegend.'
ft = ''

cmr_vg = 'Zum Vergleich liegt zuletzt eine MRT des Schädels vom '
cct_vg = 'Zum Vergleich liegt zuletzt eine CT des Schädels vom '

vergleich = widgets.HTML(value="<i>Vergleich:</i>")

##Vegleich RadioButtons
vgl = widgets.RadioButtons(
    options=['Keine Vergleichsuntersuchung', 'cMR zum Vergleich vom:', 'cCT zum Vergleich vom:'],
    #value=,
    disabled=False
)

##Datumsfeld
date = widgets.Text(
    layout={'width': '250px'},
    placeholder='Datum',
    description='Voruntersuchung:',
    style={'description_width': 'initial'},
    disabled=False
)

# Befundkörper

## Befundelemente
d_no_met = 'Keine Metastasen'
no_met = 'Keine suspekten KM-Anreicherungen intrakraniell.'

d_isch = 'Keine Ischämie'
isch = 'Keine frische Ischämiedemarkation.'

d_blu = 'Keine Blutung'
blu = 'Keine intrakranielle Blutung.'

d_reg = 'Beschreibung graue und weiße Substanz'
mik = 'Mehrere fleckförmige FLAIR-Hyperintensitäten der Marklager i.S. mikroangiopathischer Veränderungen.'
reg = 'Regelrechte Signalgebung von grauer und weißer Substanz.'
s_reg = 'Sonst regelrechte Signalgebung von grauer und weißer Substanz.'

d_liq = 'Regelrechte Liqourräume'
liq = 'Mittelständiger Interhemissphärenspalt. Altersentsprechende Weite der inneren und äußeren Liquorräume. Keine Zeichen einer Liquorzirkulationsstörung.'

d_nnh = 'Regelrechte NNH und Ohrnebenräume'
nnh = 'Nasennebenhöhlen und Ohrnebenräume frei belüftet.'

## Widgtes Befundelemente
layout = widgets.Layout(width='300px', height='auto') # Breite und Höhe festlegen
### Keine Metastasen
no_met_but = widgets.RadioButtons(
    options=[('Keine Metastasen', no_met), ('Freitext', ft)],
    description='Metastasen:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

no_met_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

### Keine Ischämie
isch_but = widgets.RadioButtons(
    options=[('Keine Ischämie', isch), ('Freitext', ft)],
    description='Ischämie:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

isch_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

### Keine Blutung
blu_but = widgets.RadioButtons(
    options=[('Keine Blutung', blu), ('Freitext', ft)],
    description='Blutung:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

blu_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

### Mark/Rinden
#### MR
reg_but = widgets.RadioButtons(
    options=[('Mikroangiopathie', mik), ('Regelrecht', reg), ('Freitext', ft)],
    description='Hirnparenchym:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

reg_check = widgets.Checkbox(
    layout={'width': 'max-content'},
    description='Sonst regelrechte Signalgebung',
    value=False
)

reg_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

### Liquor
liq_but = widgets.RadioButtons(
    options=[('Regelrechte Liquorräume', blu), ('Freitext', ft)],
    description='Liquorräume:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

liq_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

### NNH
nnh_but = widgets.RadioButtons(
    options=[('Regelrechte NNH', blu), ('Freitext', ft)],
    description='NNH/Mastoid:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

nnh_check = widgets.Checkbox(
    layout = layout,
    description='Im Übrigen regelrechte Belüftung',
    value=False
)

nnh_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

#### Elemente cCT

# Hirnparenchym
mak = 'Mikro- und Makroangiopathische Veränderungen.'
reg_ct = 'Ausreichende Differenzierbarkeit von grauer und weißer Substanz.'
s_reg_ct = 'Sonst ausreichende Differenzierbarkeit von grauer und weißer Substanz.'

dif_but = widgets.RadioButtons(
    options=[('Mikro-/Makroangiopathie', mak), ('Regelrecht', reg_ct), ('Freitext', ft)],
    description='Hirnparenchym:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

reg_ct_check = widgets.Checkbox(
    layout={'width': 'max-content'},
    description='Sonst regelrechte Differenzierbarkeit',
    value=False
)

# Knochen
oss = 'Regelrechte Darstellung der erfassten Skelettabschnitte.'
s_oss = 'Sonst regelrechte Darstellung der erfassten Skelettabschnitte.'

oss_but = widgets.RadioButtons(
    options=[('Regelrechter Knochen', oss), ('Freitext', ft)],
    description='Knochen:',
    style={'description_width': '100px'},
    layout=layout,
    disabled=False
)

oss_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

oss_check = widgets.Checkbox(
    layout={'width': 'max-content'},
    description='Sonst regelrechte Darstellung',
    value=False
)

## BEURTEILUNG
ber = 'Beurteilung:'
nb = ''
ber_no_met = 'Kein Nachweis intrakranieller Metastasen.'
ft = ''

ber_but = widgets.RadioButtons(
    options=[('Keine Metastasen', ber_no_met), ('Freitext', ft)],
    placeholder='Freitext',
    style={'description_width': '100px'},
    description=' ',
    layout=layout,
    disabled=False
)

ber_text = widgets.Textarea(
    layout={'height':'auto', 'width':'550px'},
    value='',
    placeholder='Freitext',
    disabled=False
)

##Befundkörper als HBox
left_box1 = widgets.VBox([no_met_but])
right_box1 = widgets.VBox([no_met_text])
items_box1 = widgets.HBox([left_box1, right_box1])

left_box2 = widgets.VBox([isch_but])
right_box2 = widgets.VBox([isch_text])
items_box2 = widgets.HBox([left_box2, right_box2])

left_box3 = widgets.VBox([blu_but])
right_box3 = widgets.VBox([blu_text])
items_box3 = widgets.HBox([left_box3, right_box3])

left_box4 = widgets.VBox([reg_but])
right_box4 = widgets.VBox([reg_text, reg_check])
items_box4 = widgets.HBox([left_box4, right_box4])

left_box5 = widgets.VBox([liq_but])
right_box5 = widgets.VBox([liq_text])
items_box5 = widgets.HBox([left_box5, right_box5])

left_box6 = widgets.VBox([nnh_but])
right_box6 = widgets.VBox([nnh_text, nnh_check])
items_box6 = widgets.HBox([left_box6, right_box6])

### Elemente cCT als HBox
left_box7 = widgets.VBox([dif_but])
right_box7 = widgets.VBox([reg_text, reg_ct_check])
items_box7 = widgets.HBox([left_box7, right_box7])

left_box8 = widgets.VBox([oss_but])
right_box8 = widgets.VBox([oss_text, oss_check])
items_box8 = widgets.HBox([left_box8, right_box8])

##Beurteilung als HBox
left_box2 = widgets.VBox([ber_but])
right_box2 = widgets.VBox([ber_text])
ber_items_box = widgets.HBox([left_box2, right_box2])

# Befund erstellen.
def tb():
  if type(opt_text.value) == str and type(opt_text.value) != '':
    print(opt_text.value)

## Befund MRT
def befundtext_mr():
  if vgl.value == 'Keine Vergleichsuntersuchung':
    print(kvgl) 
    print('')
  elif vgl.value == 'cMR zum Vergleich vom:':
    print(cmr_vg + date.value + ' vor.')
    print('')
  else:
    print(cct_vg + date.value + ' vor.')
    print('')
  # Befundelemente
  if no_met_but.value == ft:
    print(no_met_text.value)
  else:
    print(no_met)
  
  if isch_but.value == ft:
    print(isch_text.value)
  else:
    print(isch)

  if blu_but.value == ft:
    print(blu_text.value)
  else:
    print(blu)

  #---------------------------- 
  #Hirnparenchym 
  ##MR
  if reg_but.value == mik:
    print(mik)
  elif reg_but.value == reg:
    print(reg)
  else:
    print(reg_text.value)
  if reg_check.value == True:
    print(s_reg)
  #--------------------------

  if liq_but.value == ft:
    print(liq_text.value)
  else:
    print(liq)

  if nnh_but.value == ft:
    print(nnh_text.value)
  else:
    print(nnh)
  if nnh_check.value == True:
    print('Im Übrigen freie Belüftung der NNH und Mastoidzellen.')
  # Beurteilung
  print('')
  print('Beurteilung:')
  if ber_but.value == ft:
    print(ber_text.value)
  else:
    print(ber_no_met)
  
  # Befundmitteilung 
  print('')
  if drop.value == mkoll:
    print(drop.value+' erfolgt.')
  if drop.value == wkoll: 
    print(drop.value+' '+name.value+'erfolgt.')
  if drop.value == spkoll:
    print('Befundmitteilung an '+name.value+' erfolgt.') 
  print('')

## Befund CT
def befundtext_ct():
  if vgl.value == 'Keine Vergleichsuntersuchung':
    print(kvgl) 
    print('')
  elif vgl.value == 'cMR zum Vergleich vom:':
    print(cmr_vg + date.value + ' vor.')
    print('')
  else:
    print(cct_vg + date.value + ' vor.')
    print('')
  # Befundelemente
  if no_met_but.value == ft:
    print(no_met_text.value)
  else:
    print(no_met)
  
  if isch_but.value == ft:
    print(isch_text.value)
  else:
    print(isch)

  if blu_but.value == ft:
    print(blu_text.value)
  else:
    print(blu)

  #---------------------------- 
  #Hirnparenchym 
  ##CT
  if dif_but.value == mak:
    print(mak)
  elif dif_but.value == reg_ct:
    print(reg_ct)
  else:
    print(reg_text.value)
  if reg_ct_check.value == True:
    print(s_reg_ct)
  #--------------------------

  if liq_but.value == ft:
    print(liq_text.value)
  else:
    print(liq)

  if nnh_but.value == ft:
    print(nnh_text.value)
  else:
    print(nnh)
  if nnh_check.value == True:
    print('Im Übrigen freie Belüftung der NNH und Mastoidzellen.')
  
  if oss_but.value == oss:
    print(oss)
  else:
    print(oss_text.value)
  if oss_check.value == True:
    print(s_oss)
  
  # Beurteilung
  print('')
  print('Beurteilung:')
  if ber_but.value == ft:
    print(ber_text.value)
  else:
    print(ber_no_met)
  
  # Befundmitteilung 
  print('')
  if drop.value == mkoll:
    print(drop.value+' erfolgt.')
  if drop.value == wkoll: 
    print(drop.value+' '+name.value+'erfolgt.')
  if drop.value == spkoll:
    print('Befundmitteilung an '+name.value+' erfolgt.') 
  print('')

# Befundmitteilung

kein = 'Keine Befundmitteilung'
spkoll = 'Befundmitteilung an folgenden Kollegen:'
mkoll = 'Befundmitteilung an den behandelnden Kollegen'
wkoll = 'Befundmitteilung an die behandelnde Kollegin'

drop = widgets.Dropdown(
    options=[kein, mkoll, wkoll, spkoll],
    value=kein,
    description='Mitteilung:',
    disabled=False,
)

name = widgets.Text(
    #value=,
    placeholder='Name',
    description='Kliniker:',
    disabled=False
)

## Button für die Befunderstellung MR
button = widgets.Button(description="Befund erstellen")
button.style.button_color='lightblue'
output = widgets.Output()

def on_button_clicked(b):
    with output:
        output.clear_output()
        print('')
        print('-------------------------------------------------------------------')
        befundtext_mr()
button.on_click(on_button_clicked)

## Button für die Befunderstellung CT
button_ct = widgets.Button(description="Befund erstellen")
button_ct.style.button_color='lightblue'
output_ct = widgets.Output()

def on_button_ct_clicked(b):
    with output_ct:
        output.clear_output()
        print('')
        print('-------------------------------------------------------------------')
        befundtext_ct()
button_ct.on_click(on_button_ct_clicked)

# Erstellen des Layouts als Accordion
list_widgets  = [
    widgets.VBox([widgets.HTML(value="<i>Vergleich:</i>"), 
                  vgl, 
                  date, 
                  widgets.HTML(value="<i>Befund:</i>"),
                  items_box1,
                  items_box2,
                  items_box3,
                  items_box4,
                  items_box5,
                  items_box6,
                  widgets.HTML(value="<i>Beurteilung:</i>"),
                  ber_items_box,
                  widgets.HTML(value="<i>Befundmitteilung:</i>"),
                  drop,
                  name,
                  button,
                  output
                  ]),
    widgets.VBox([widgets.HTML(value="<i>Vergleich:</i>"), 
                  vgl, 
                  date, 
                  widgets.HTML(value="<i>Befund:</i>"),
                  items_box1,
                  items_box2,
                  items_box3,
                  items_box7,
                  items_box5,
                  items_box6,
                  items_box8,
                  widgets.HTML(value="<i>Beurteilung:</i>"),
                  ber_items_box,
                  widgets.HTML(value="<i>Befundmitteilung:</i>"),
                  drop,
                  name,
                  button_ct,
                  output_ct
                  ])
                ]

accordion = widgets.Accordion(children=list_widgets)
accordion.set_title(0, 'cMR')
accordion.set_title(1, 'cCT')
accordion
# Out:
# Accordion(children=(VBox(children=(HTML(value='<i>Vergleich:</i>'), RadioButtons(options=('Keine Vergleichsunt…
